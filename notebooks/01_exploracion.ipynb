# %%
import pandas as pd

df_historico = pd.read_excel('../data/raw/precios_comb_liquidos_en_el_pais-2026-08-03.xlsx')
df_historico.shape
# Out:
# (0, 0)

# %%
xls = pd.ExcelFile('../data/raw/precios_comb_liquidos_en_el_pais-2026-08-03.xlsx')
print(xls.sheet_names)
# Out:
# ['Hoja1', 'Gasolina 93 sp', 'Gasolina 95 sp', 'Gasolina 97 sp', 'Petróleo Diesel', 'Kerosene Doméstico']

# %%
df_93 = pd.read_excel('../data/raw/precios_comb_liquidos_en_el_pais-2026-08-03.xlsx', sheet_name='Gasolina 93 sp')
df_93.shape
# Out:
# (402, 18)

# %%
df_93.head(10)
# Out:
#    Unnamed: 0                                         Unnamed: 1  \
# 0         NaN  FUENTE HASTA DICIEMBRE 2012: ENCUESTA DE PRECI...
# 1         NaN  FUENTE DESDE ENERO 2013: Corresponde al precio...
# 2         NaN                                 ND:  NO DISPONIBLE
# 3         NaN                                     NE:  NO EXISTE
# 4         NaN                                                NaN
# 5         NaN                                           GASOLINA
# 6         NaN                                             93 S/P
# 7         NaN                                                NaN
# 8         NaN                                              Fecha
# 9         NaN                                1994-01-01 00:00:00
#
#   PRECIOS OBSERVADOS A PÚBLICO: PROMEDIOS NOMINALES EN REGIONES Y REGIÓN METROPOLITANA ($/LITRO)  \
# 0                                                NaN
# 1                                                NaN
# ...

# %%
df_93 = pd.read_excel(
    '../data/raw/precios_comb_liquidos_en_el_pais-2026-08-03.xlsx',
    sheet_name='Gasolina 93 sp',
    header=9
)
df_93.head()
# Out:
#    Unnamed: 0           Unnamed: 1      Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0         NaN                Fecha   METROPOLITANA      ARICA    IQUIQUE
# 1         NaN  1994-01-01 00:00:00           166.5        NaN      179.4
# 2         NaN  1994-02-01 00:00:00           166.3        NaN      179.6
# 3         NaN  1994-03-01 00:00:00           166.3        NaN      179.6
# 4         NaN  1994-04-01 00:00:00           170.7        NaN      184.9
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7  Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  ANTOFAGASTA    COPIAPÓ  LA SERENA  VALPARAÍSO   RANCAGUA       TALCA
# 1        180.9      181.7      179.6       174.8      173.1       175.3
# 2           ND      181.7      180.7       174.5      173.2       175.3
# 3          181      181.7      179.8       174.7      173.2       175.3
# 4        185.7      185.5      184.5       179.2      178.2       182.2
#
#   Unnamed: 11  Unnamed: 12 Unnamed: 13 Unnamed: 14    Unnamed: 15 Unnamed: 16  \
# ...
